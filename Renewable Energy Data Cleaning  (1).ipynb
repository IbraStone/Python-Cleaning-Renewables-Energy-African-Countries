# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #  Cleaning dataset Renewable Energy  in Africa from US Energy Information Administration

# %%
# Load dataset and display dataset

Renewable_energy_AfricaPy = pd.read_csv('C:/Users/ibrah/OneDrive/Desktop/Data Analytics Certificate Program/Renewable_energy_AfricaPy.csv')
print(Renewable_energy_AfricaPy)
# Out:
#       Country                   Energy Source (billion kWh)   1980   1981  \
# 0     Algeria                             Hydroelectricity   0.248  0.362
# 1     Algeria                                    Geothermal      0      0
# 2     Algeria                  Solar, tide, wave, fuel cell      0      0
# 3     Algeria                                Tide and wave       0      0
# 4     Algeria                                        Solar       0      0
# ..        ...                                           ...    ...    ...
# 402  Zimbabwe                  Solar, tide, wave, fuel cell      0      0
# 403  Zimbabwe                                Tide and wave       0      0
# 404  Zimbabwe                                        Solar       0      0
# 405  Zimbabwe                                         Wind       0      0
# 406  Zimbabwe                            Biomass and waste       0      0
#
#       1982   1983   1984   1985   1986   1987  ...   2012   2013   2014  \
# ...

# %% [markdown]
#  #### Handling Missing data

# %%
# Check for missing values in the entire dataset
missing_values = Renewable_energy_AfricaPy.isnull().sum()

# If you want to see the missing values as a percentage of the total for each column:
missing_percent = (missing_values / len(Renewable_energy_AfricaPy)) * 100

# Create a DataFrame to display the missing values and percentages
missing_data = pd.DataFrame({'Missing_Values': missing_values, 'Percentage': missing_percent})

# Print or display the missing data
print(missing_data)
# Out:
#                              Missing_Values  Percentage
# Country                                  50   12.285012
# Energy Source (billion kWh)              50   12.285012
# 1980                                     50   12.285012
# 1981                                     50   12.285012
# 1982                                     50   12.285012
# 1983                                     50   12.285012
# 1984                                     50   12.285012
# 1985                                     50   12.285012
# 1986                                     50   12.285012
# 1987                                     50   12.285012
# 1988                                     50   12.285012
# 1989                                     50   12.285012
# 1990                                     50   12.285012
# 1991                                     50   12.285012
# 1992                                     50   12.285012
# 1993                                     50   12.285012
# ...

# %%
# Impute missing values in numerical columns with the mean
numerical_columns = Renewable_energy_AfricaPy.select_dtypes(include=['number'])
Renewable_energy_AfricaPy[numerical_columns.columns] = numerical_columns.fillna(numerical_columns.mean())

# Impute missing values in categorical columns with the mode
categorical_columns = Renewable_energy_AfricaPy.select_dtypes(include=['object'])
Renewable_energy_AfricaPy[categorical_columns.columns] = categorical_columns.fillna(categorical_columns.mode().iloc[0])

# Print the updated DataFrame
print(Renewable_energy_AfricaPy)
# Out:
#       Country                   Energy Source (billion kWh)   1980   1981  \
# 0     Algeria                             Hydroelectricity   0.248  0.362
# 1     Algeria                                    Geothermal      0      0
# 2     Algeria                  Solar, tide, wave, fuel cell      0      0
# 3     Algeria                                Tide and wave       0      0
# 4     Algeria                                        Solar       0      0
# ..        ...                                           ...    ...    ...
# 402  Zimbabwe                  Solar, tide, wave, fuel cell      0      0
# 403  Zimbabwe                                Tide and wave       0      0
# 404  Zimbabwe                                        Solar       0      0
# 405  Zimbabwe                                         Wind       0      0
# 406  Zimbabwe                            Biomass and waste       0      0
#
#       1982   1983   1984   1985   1986   1987  ...   2012   2013   2014  \
# ...

# %% [markdown]
#  #### Remove duplicate

# %%
# Use the .drop_duplicates() method to remove duplicate rows
Renewable_energy_AfricaPy = Renewable_energy_AfricaPy.drop_duplicates(keep='last')
# Print the updated DataFrame
print(Renewable_energy_AfricaPy)
# Out:
#       Country                   Energy Source (billion kWh)   1980   1981  \
# 0     Algeria                             Hydroelectricity   0.248  0.362
# 1     Algeria                                    Geothermal      0      0
# 2     Algeria                  Solar, tide, wave, fuel cell      0      0
# 3     Algeria                                Tide and wave       0      0
# 4     Algeria                                        Solar       0      0
# ..        ...                                           ...    ...    ...
# 402  Zimbabwe                  Solar, tide, wave, fuel cell      0      0
# 403  Zimbabwe                                Tide and wave       0      0
# 404  Zimbabwe                                        Solar       0      0
# 405  Zimbabwe                                         Wind       0      0
# 406  Zimbabwe                            Biomass and waste       0      0
#
#       1982   1983   1984   1985   1986   1987  ...   2012   2013   2014  \
# ...

# %% [markdown]
#  #### Drop columns

# %%
print(Renewable_energy_AfricaPy.columns)
# Out:
# Index(['Country', 'Energy Source (billion kWh)', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021'],
#       dtype='object')

# %%
# List the names of the columns you want to drop
columns_to_drop = ['1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', 
                   '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
                   '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009']

# Use the .drop() method to remove the specified columns
Renewable_energy_AfricaPy.drop(columns=columns_to_drop, inplace=True)

# Print the updated DataFrame
print(Renewable_energy_AfricaPy)
# Out:
#       Country                   Energy Source (billion kWh)    2010    2011  \
# 0     Algeria                             Hydroelectricity    0.172   0.497
# 1     Algeria                                    Geothermal       0       0
# 2     Algeria                  Solar, tide, wave, fuel cell  0.0001  0.0001
# 3     Algeria                                Tide and wave        0       0
# 4     Algeria                                        Solar   0.0001  0.0001
# ..        ...                                           ...     ...     ...
# 402  Zimbabwe                  Solar, tide, wave, fuel cell       0  0.0004
# 403  Zimbabwe                                Tide and wave        0       0
# 404  Zimbabwe                                        Solar        0  0.0004
# 405  Zimbabwe                                         Wind        0       0
# 406  Zimbabwe                            Biomass and waste    0.094   0.131
#
# ...

# %%
# View rows in my dataset after cleaning
Renewable_energy_AfricaPy_head = Renewable_energy_AfricaPy.head()

# Print  rows of the DataFrame
Renewable_energy_AfricaPy.head(50)
# Out:
#          Country                   Energy Source (billion kWh)    2010  \
# 0        Algeria                             Hydroelectricity    0.172
# 1        Algeria                                    Geothermal       0
# 2        Algeria                  Solar, tide, wave, fuel cell  0.0001
# 3        Algeria                                Tide and wave        0
# 4        Algeria                                        Solar   0.0001
# 5        Algeria                                         Wind        0
# 6        Algeria                            Biomass and waste        0
# 8         Angola                             Hydroelectricity    3.666
# 9         Angola                                    Geothermal       0
# 10        Angola                  Solar, tide, wave, fuel cell    0.01
# 11        Angola                                Tide and wave        0
# 12        Angola                                        Solar     0.01
# ...

# %%
# Replace 'df' with your actual DataFrame name
grouped_data = Renewable_energy_AfricaPy.groupby('Country').sum(numeric_only=True)

# Reset the index to have 'Country' as a regular column
grouped_data = grouped_data.reset_index()

# Print the resulting DataFrame
print(grouped_data)
# Out:
#                      Country       2012       2013       2014       2015  \
# 0                    Algeria   0.943183   0.673270   0.628540   0.669762
# 1                     Angola   3.762000   4.749000   5.061000   5.115000
# 2                      Benin   0.001000   0.002000   0.002000   0.011000
# 3                   Botswana   0.002000   0.004000   0.006000   0.006000
# 4               Burkina Faso   0.115000   0.126000   0.112000   0.119000
# 5                    Burundi   0.149000   0.151000   0.154000   0.152000
# 6                 Cabo Verde   0.079000   0.090000   0.097000   0.091000
# 7                   Cameroon   4.221440   4.339270   4.345270   4.335410
# 8   Central African Republic   0.149800   0.137800   0.168800   0.168800
# 9                       Chad   0.009000   0.009200   0.009200   0.009600
# 10         Congo-Brazzaville   0.977200   0.961600   0.942600   1.089000
# 11            Congo-Kinshasa   7.510200   8.149000   8.734000   8.829000
# ...
